# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import LeavePOut
from sklearn.model_selection import StratifiedShuffleSplit

# %% [markdown]
# # Importing Data

# %% [markdown]
# Below the Dataset 7 and Dataset 8 are downloaded. The information for the chemicals that were used to treat the 3D Neural constructs are also downloaded. Dataset 7 represents Normalized gene expression (TPM) for day 16 neural constructs after dosing with toxic or non-toxic chemicals (two days of exposure). Dataset 8 represents Normalized gene expression (TPM) for day 21 neural constructs after dosing with toxic or non-toxic chemicals (seven days of exposure). 3D Neural constructs were grown for 14 days before chemical exposure.

# %%
day_21_df = pd.read_csv('/Users/danielaquijano/Documents/GitHub/Machine-Learning-Course-Projects/Final_Project_Neurotoxicity_Prediction/Final_Project_Files/Day_21_RNA_seq.csv')
day_21_df
# Out:
#       Gene.ID                                      Transcript_ID  day 21 b1a  \
# 0        A1BG                                        NM_130786.1        8.21
# 1        A1CF  NM_001198818.1,NM_001198819.1,NM_001198820.1,N...        0.00
# 2       A2LD1                         NM_001195087.1,NM_033110.1        1.65
# 3         A2M                                        NM_000014.1      314.44
# 4       A2ML1                                        NM_144670.1        0.55
# ...       ...                                                ...         ...
# 19079  ZYG11A                                     NM_001004339.1        1.12
# 19080  ZYG11B                                        NM_024646.1       42.05
# 19081     ZYX                         NM_001010972.1,NM_003461.1       79.69
# 19082   ZZEF1                                        NM_015113.1       17.13
# 19083    ZZZ3                                        NM_015534.1       24.20
#
#        day 21 b1b  day 21 b2a  day 21 b2b  day 21 b3a  day 21 b3b  day 21 b4a  \
# 0            7.16       19.99       20.77       14.20        9.60       12.10
# 1            0.00        0.00        0.00        0.16        0.14        0.00
# 2            3.56        3.17        1.49        3.30        6.32        5.98
# 3          321.66       77.28       80.94      140.52      146.63      169.19
# 4            0.24        0.25        0.00        0.15        0.15        0.10
# ...           ...         ...         ...         ...         ...         ...
# 19079        0.48        0.15        0.31        0.22        1.49        1.60
# 19080       42.98       42.33       42.06       38.06       41.21       34.66
# 19081       55.43       87.20       74.56       81.82       74.56       78.07
# 19082       19.52       20.60       17.02       16.28       17.34       21.52
# 19083       28.32       34.07       31.24       36.57       29.15       32.43
#
#        day 21 b4b  ...  day 21 t30a  day 21 t30b  day 21 t31a  day 21 t31b  \
# 0           12.71  ...        13.54        11.81         7.19        11.88
# 1            0.00  ...         0.04         0.09         0.32         0.07
# 2            4.55  ...         3.72         2.39         3.06         4.17
# 3           93.49  ...       147.16       152.41       191.36       213.36
# 4            0.43  ...         0.00         0.18         0.14         0.00
# ...           ...  ...          ...          ...          ...          ...
# 19079        1.71  ...         0.93         0.31         1.22         0.64
# 19080       38.96  ...        44.10        44.67        49.90        45.38
# 19081       72.44  ...        89.29        80.73        87.67        65.17
# 19082       18.34  ...        19.85        20.14        23.31        19.60
# 19083       32.75  ...        29.78        33.38        28.83        29.29
#
#        day 21 t32a  day 21 t32b  day 21 t33a  day 21 t33b  day 21 t34a  \
# 0             9.75         7.73        17.22        15.17        20.44
# 1             0.00         0.03         0.05         0.09         0.00
# 2             2.59         3.65         3.53         5.18         3.04
# 3           127.01       169.79       160.04       153.30       262.29
# 4             0.14         0.12         0.38         0.38         0.33
# ...            ...          ...          ...          ...          ...
# 19079         0.74         0.65         0.76         0.64         1.76
# 19080        25.03        50.70        26.39        37.47        25.52
# 19081        99.46        72.56       107.69        76.56        96.67
# 19082        11.73        17.27        12.38        15.62        17.18
# 19083        19.82        35.13        25.86        28.23        20.63
#
#        day 21 t34b
# 0            10.83
# 1             0.05
# 2             3.00
# 3           288.09
# 4             0.19
# ...            ...
# 19079         1.46
# 19080        34.48
# 19081        82.75
# 19082        19.80
# 19083        29.34
#
# [19084 rows x 142 columns]

# %%
day_16_df = pd.read_csv('/Users/danielaquijano/Documents/GitHub/Machine-Learning-Course-Projects/Final_Project_Neurotoxicity_Prediction/Final_Project_Files/Day_16_RNA_seq.csv')
day_16_df
# Out:
#       Gene.ID                                      Transcript_ID  day 16 b1a  \
# 0        A1BG                                        NM_130786.1        9.57
# 1        A1CF  NM_001198818.1,NM_001198819.1,NM_001198820.1,N...        0.00
# 2       A2LD1                         NM_001195087.1,NM_033110.1        4.68
# 3         A2M                                        NM_000014.1      368.93
# 4       A2ML1                                        NM_144670.1        0.00
# ...       ...                                                ...         ...
# 19079  ZYG11A                                     NM_001004339.1        1.55
# 19080  ZYG11B                                        NM_024646.1       42.04
# 19081     ZYX                         NM_001010972.1,NM_003461.1       73.61
# 19082   ZZEF1                                        NM_015113.1       17.65
# 19083    ZZZ3                                        NM_015534.1       36.42
#
#        day 16 b1b  day 16 b2a  day 16 b2b  day 16 b3a  day 16 b3b  day 16 b4a  \
# 0            9.83       15.34       14.42       10.43        8.29       11.39
# 1            0.04        0.13        0.00        0.27        0.00        0.08
# 2            4.46        1.61        3.24        2.70        2.98        3.06
# 3          350.46      171.77      119.16      235.31      292.92      184.61
# 4            0.00        0.17        0.00        0.22        0.00        0.25
# ...           ...         ...         ...         ...         ...         ...
# 19079        0.79        0.92        0.00        0.61        0.02        1.99
# 19080       45.03       48.64       46.11       40.49       40.76       42.74
# 19081       80.59       86.60       82.82       81.22       73.89       67.85
# 19082       18.70       23.36       21.27       19.93       20.91       16.70
# 19083       29.80       34.04       30.66       31.74       38.20       39.83
#
#        day 16 b4b  ...  day 16 t30a  day 16 t30b  day 16 t31a  day 16 t31b  \
# 0           13.67  ...        13.81        12.15        14.24        11.22
# 1            0.00  ...         0.27         0.00         0.00         0.22
# 2            1.39  ...         3.37         2.12         2.20         2.96
# 3          172.11  ...       277.85       212.12       242.60       271.34
# 4            0.13  ...         0.00         0.00         0.00         0.25
# ...           ...  ...          ...          ...          ...          ...
# 19079        0.94  ...         0.60         1.75         1.88         0.33
# 19080       54.46  ...        37.64        45.79        41.93        42.36
# 19081       77.99  ...        57.65        73.23        83.54        81.58
# 19082       21.25  ...        17.11        22.49        20.04        20.57
# 19083       33.90  ...        26.17        34.77        31.44        28.19
#
#        day 16 t32a  day 16 t32b  day 16 t33a  day 16 t33b  day 16 t34a  \
# 0            14.95        10.58         9.75        12.41        16.38
# 1             0.00         0.19         0.00         0.19         0.00
# 2             3.54         1.85         1.95         3.50         3.85
# 3           221.18       227.61       204.09       173.85       230.21
# 4             0.15         0.31         0.00         0.00         0.39
# ...            ...          ...          ...          ...          ...
# 19079         2.18         1.04         0.52         1.82         0.63
# 19080        49.19        49.05        49.76        47.96        48.74
# 19081        77.96        88.30        72.33        85.84        76.73
# 19082        20.57        19.30        19.94        19.31        28.66
# 19083        29.80        31.80        30.89        30.06        30.70
#
#        day 16 t34b
# 0            10.78
# 1             0.19
# 2             3.55
# 3           323.13
# 4             0.09
# ...            ...
# 19079         1.12
# 19080        39.63
# 19081       106.11
# 19082        21.23
# 19083        29.42
#
# [19084 rows x 142 columns]

# %% [markdown]
# ### Data Clean-up

# %% [markdown]
# Next, combine day_16_df and day_21_df into a single dataframe that reflects the averge values of gene expression between the the two dataframes

# %%
for i in range(len(raw_data)):
    for j in range(1, len(raw_data.columns)):
        raw_data_normalized.iat[i,j]=(int(raw_data.iat[i,j])*1000000)/int(raw_cols_sums[j])

# %% [markdown]
# Log-2 fold change

# %% [markdown]
# Visualize Normalization with boxplot

# %% [markdown]
# Visualize Log-2fold change

# %% [markdown]
# Add labels of toxic/nontoxic

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Heat map of genes with log2 fold change above a specific thershold

# %% [markdown]
# ### PCA

# %% [markdown]
# ### Unsupervised Clustering

# %%
Multidimensional Scaling

# %% [markdown]
# ### GO term enrichment

# %% [markdown]
# ### Differentially Expressed Genes

# %% [markdown]
# ### Obtain Top 100 Differentially Expressed Genes

# %%
Visualizing Top 100 Differentially Expressed Gnes

# %% [markdown]
# # Implementation of Classification Algorithms

# %%
Support Vector Machines
