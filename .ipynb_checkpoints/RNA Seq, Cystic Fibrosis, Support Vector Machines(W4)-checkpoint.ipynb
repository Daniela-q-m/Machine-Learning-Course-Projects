# %% [markdown]
# The purpose of this notebook is to apply the support vector machines model to RNA Seq Data. The data comes fro the study by Kopp et al. The experiment aimed to determine the effectiveness of a medication, Lumacaftor/ivacaftor, for Cystic Fibrosis. The experiment involved a total of 40 patients. 20 healthy control and 20 with Cystic Fibrosis. The 20 with CF were also treated with a medication Lumacaftor/ivacaftor for a total of 60 samples.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns #For visualizatin
# %matplotlib inline
from sklearn.metrics import classification_report,confusion_matrix #For analysis after model application
from sklearn.model_selection import train_test_split #To train SVM model
from sklearn.model_selection import GridSearchCV #To change parameters in the SVM

# %%
data_df = pd.read_excel ('/Users/danielaquijano/Documents/GitHub/Machine-Learning-Course-Projects/sourcefiles/GSE124548_RNAseq.xlsx')
data_df.head()
# Out:
#    RowID        ID                         Description  EntrezID  \
# 0      1      A1BG              alpha-1-B glycoprotein         1
# 1      2  A1BG-AS1                A1BG antisense RNA 1    503538
# 2      3   A2M-AS1  A2M antisense RNA 1 (head to head)    144571
# 3      4      AAAS        aladin WD repeat nucleoporin      8086
# 4      5      AACS          acetoacetyl-CoA synthetase     65985
#
#             Class  pre_drug.vs.control_ShrunkenLog2FC  \
# 0  protein_coding                           -0.050497
# 1          lncRNA                            0.004178
# 2          lncRNA                            0.356337
# 3  protein_coding                           -0.139005
# 4  protein_coding                            0.138032
#
#    pre_drug.vs.control_MLELog2FC  pre_drug.vs.control_pVal  \
# 0                      -0.066327                  0.691693
# 1                       0.032895                  0.971929
# 2                       0.932311                  0.050847
# 3                      -0.152091                  0.285215
# 4                       0.143003                  0.088856
#
#    pre_drug.vs.control_pAdj  post_drug.vs.control_ShrunkenLog2FC  ...  \
# 0                  0.824882                             0.082631  ...
# 1                  0.986309                             0.155902  ...
# 2                  0.179776                            -0.359549  ...
# 3                  0.495514                            -0.118870  ...
# 4                  0.251817                             0.075925  ...
#
#    Raw_Orkambi_021_Base  Raw_Orkambi_021_V2  Raw_Orkambi_022_Base  \
# 0                   113                  89                    31
# 1                    40                  36                    26
# 2                    16                  23                    40
# 3                   130                  71                    28
# 4                   192                 157                    71
#
#    Raw_Orkambi_022_V2  Raw_Orkambi_024_Base  Raw_Orkambi_024_V2  \
# 0                 125                    44                  78
# 1                  87                    23                  72
# 2                 104                   370                 199
# 3                 178                    62                 219
# 4                 228                   130                 185
#
#    Raw_Orkambi_025_Base  Raw_Orkambi_025_V2  Raw_Orkambi_026_Base  \
# 0                   113                  98                    38
# 1                    74                  55                    64
# 2                    81                  30                   228
# 3                   176                 106                   160
# 4                   198                 114                   131
#
#    Raw_Orkambi_026_V2
# 0                  70
# 1                  53
# 2                  33
# 3                 121
# 4                 157
#
# [5 rows x 140 columns]

# %% [markdown]
# Possible comparisons to perform:
#
# An upaired analysis comparing healthy vs cystic fibrosis. These will identify genes that can distinguish a healthy patient from one with CF.
#
# A paired analysis comparing the CF patients before and after treatment. This will give us an idea of how the CF patients are responding to the treatment. However we expect this to be noisy since the motivation for this experiment was that not all patients are responding similarly.

# %% [markdown]
# Expression data from the top 10 most differentially expressed genes will be used for unpaired analysis.

# %% [markdown]
# First test how well it can perform in predicting Healthy and CF patients, and then we will pretend the CF treated is our test set and make our prediction.

# %%
#Trim dataframe to only contain 60 columns
#Get column names/dataset information
data_df.info()
for col in data_df.columns:
    print(col)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15570 entries, 0 to 15569
# Columns: 140 entries, RowID to Raw_Orkambi_026_V2
# dtypes: float64(75), int64(62), object(3)
# memory usage: 16.6+ MB
# RowID
# ID
# Description
# EntrezID
# Class
# pre_drug.vs.control_ShrunkenLog2FC
# pre_drug.vs.control_MLELog2FC
# pre_drug.vs.control_pVal
# pre_drug.vs.control_pAdj
# post_drug.vs.control_ShrunkenLog2FC
# post_drug.vs.control_MLELog2FC
# post_drug.vs.control_pVal
# post_drug.vs.control_pAdj
# post_drug.vs.pre_drug_ShrunkenLog2FC
# post_drug.vs.pre_drug_MLELog2FC
# post_drug.vs.pre_drug_pVal
# post_drug.vs.pre_drug_pAdj
# control_Mean
# pre-drug_Mean
# post-drug_Mean
# Norm_10_HC_Auto_066_237
# Norm_11_Orkambi_006_Base
# Norm_12_Orkambi_007_V2
# Norm_13_HC_Auto_068_239
# Norm_14_Orkambi_007_Base
# Norm_15_Orkambi_009_V2
# Norm_16_HC_Auto_072_243
# Norm_17_Orkambi_009_Base
# Norm_18_Orkambi_010_V2
# Norm_19_HC_Auto_074_245
# Norm_1_Orkambi_001_Base
# Norm_20_Orkambi_010_Base
# Norm_21_HC_Immune_004
# Norm_22_Orkambi_012_V2
# Norm_23_HC_Auto_076_247
# Norm_24_Orkambi_012_Base
# Norm_25_Orkambi_013_V2
# Norm_26_HC_Auto_078_249
# Norm_27_Orkambi_013_Base
# Norm_28_Orkambi_014_V2
# Norm_29_HC_Auto_080_251
# Norm_2_Orkambi_001_V2
# Norm_30_Orkambi_014_Base
# Norm_3_HC_Auto_062_233
# Norm_42_HC_Auto_089_261
# Norm_4_HC_Immune_002
# Norm_5_Orkambi_002_Base
# Norm_6_Orkambi_004_V2
# Norm_7_HC_Auto_064_235
# Norm_8_Orkambi_004_Base
# Norm_9_Orkambi_006_V2
# Norm_HC_Auto_082_253
# Norm_HC_Auto_084_255
# Norm_HC_Auto_088_259
# Norm_HC_Auto_091_263
# Norm_HC_Auto_093_265
# Norm_HC_Auto_095_267
# Norm_HC_Immune_006
# Norm_HC_Immune_008
# Norm_Orkambi_015_Base
# Norm_Orkambi_015_V2
# Norm_Orkambi_016_Base
# Norm_Orkambi_016_V2
# Norm_Orkambi_017_Base
# Norm_Orkambi_017_V2
# Norm_Orkambi_018_Base
# Norm_Orkambi_018_V2
# Norm_Orkambi_019_V2
# Norm_Orkambi_020_Base
# Norm_Orkambi_020_V2
# Norm_Orkambi_021_Base
# Norm_Orkambi_021_V2
# Norm_Orkambi_022_Base
# Norm_Orkambi_022_V2
# Norm_Orkambi_024_Base
# Norm_Orkambi_024_V2
# Norm_Orkambi_025_Base
# Norm_Orkambi_025_V2
# Norm_Orkambi_026_Base
# Norm_Orkambi_026_V2
# Raw_10_HC_Auto_066_237
# Raw_11_Orkambi_006_Base
# Raw_12_Orkambi_007_V2
# Raw_13_HC_Auto_068_239
# Raw_14_Orkambi_007_Base
# Raw_15_Orkambi_009_V2
# Raw_16_HC_Auto_072_243
# Raw_17_Orkambi_009_Base
# Raw_18_Orkambi_010_V2
# Raw_19_HC_Auto_074_245
# Raw_1_Orkambi_001_Base
# Raw_20_Orkambi_010_Base
# Raw_21_HC_Immune_004
# Raw_22_Orkambi_012_V2
# Raw_23_HC_Auto_076_247
# Raw_24_Orkambi_012_Base
# Raw_25_Orkambi_013_V2
# Raw_26_HC_Auto_078_249
# Raw_27_Orkambi_013_Base
# Raw_28_Orkambi_014_V2
# Raw_29_HC_Auto_080_251
# Raw_2_Orkambi_001_V2
# Raw_30_Orkambi_014_Base
# Raw_3_HC_Auto_062_233
# Raw_42_HC_Auto_089_261
# Raw_4_HC_Immune_002
# Raw_5_Orkambi_002_Base
# Raw_6_Orkambi_004_V2
# Raw_7_HC_Auto_064_235
# Raw_8_Orkambi_004_Base
# Raw_9_Orkambi_006_V2
# Raw_HC_Auto_082_253
# Raw_HC_Auto_084_255
# Raw_HC_Auto_088_259
# Raw_HC_Auto_091_263
# Raw_HC_Auto_093_265
# Raw_HC_Auto_095_267
# Raw_HC_Immune_006
# Raw_HC_Immune_008
# Raw_Orkambi_015_Base
# Raw_Orkambi_015_V2
# Raw_Orkambi_016_Base
# Raw_Orkambi_016_V2
# Raw_Orkambi_017_Base
# Raw_Orkambi_017_V2
# Raw_Orkambi_018_Base
# Raw_Orkambi_018_V2
# Raw_Orkambi_019_V2
# Raw_Orkambi_020_Base
# Raw_Orkambi_020_V2
# Raw_Orkambi_021_Base
# Raw_Orkambi_021_V2
# Raw_Orkambi_022_Base
# Raw_Orkambi_022_V2
# Raw_Orkambi_024_Base
# Raw_Orkambi_024_V2
# Raw_Orkambi_025_Base
# Raw_Orkambi_025_V2
# Raw_Orkambi_026_Base
# Raw_Orkambi_026_V2

# %%
#Obtain column numbers to extract 60 column raw data
print(data_df.columns.get_loc("Raw_10_HC_Auto_066_237"))
print(data_df.columns.get_loc('Raw_Orkambi_026_V2'))
# Out:
# 80
# 139

# %%
#Slice Dataframe to only include raw data
raw_data=data_df.iloc[:,80:140]

# %%
#Add gene id names to the raw data
gene_ids=data_df["ID"]
raw_data.insert(0, "Gene_ID", gene_ids)
raw_data.head()
# Out:
#     Gene_ID  Raw_10_HC_Auto_066_237  Raw_11_Orkambi_006_Base  \
# 0      A1BG                      81                       38
# 1  A1BG-AS1                      49                       31
# 2   A2M-AS1                      74                      108
# 3      AAAS                     161                       86
# 4      AACS                     199                      128
#
#    Raw_12_Orkambi_007_V2  Raw_13_HC_Auto_068_239  Raw_14_Orkambi_007_Base  \
# 0                    112                      46                       64
# 1                     84                      26                       38
# 2                     62                      47                       41
# 3                    197                      92                      116
# 4                    198                     117                      162
#
#    Raw_15_Orkambi_009_V2  Raw_16_HC_Auto_072_243  Raw_17_Orkambi_009_Base  \
# 0                    196                     125                      140
# 1                     86                      80                       76
# 2                     31                     105                       45
# 3                    143                     243                      136
# 4                    263                     218                      243
#
#    Raw_18_Orkambi_010_V2  ...  Raw_Orkambi_021_Base  Raw_Orkambi_021_V2  \
# 0                     72  ...                   113                  89
# 1                     38  ...                    40                  36
# 2                     63  ...                    16                  23
# 3                    151  ...                   130                  71
# 4                    201  ...                   192                 157
#
#    Raw_Orkambi_022_Base  Raw_Orkambi_022_V2  Raw_Orkambi_024_Base  \
# 0                    31                 125                    44
# 1                    26                  87                    23
# 2                    40                 104                   370
# 3                    28                 178                    62
# 4                    71                 228                   130
#
#    Raw_Orkambi_024_V2  Raw_Orkambi_025_Base  Raw_Orkambi_025_V2  \
# 0                  78                   113                  98
# 1                  72                    74                  55
# 2                 199                    81                  30
# 3                 219                   176                 106
# 4                 185                   198                 114
#
#    Raw_Orkambi_026_Base  Raw_Orkambi_026_V2
# 0                    38                  70
# 1                    64                  53
# 2                   228                  33
# 3                   160                 121
# 4                   131                 157
#
# [5 rows x 61 columns]

# %% [markdown]
# ### Normalizing the data

# %% [markdown]
# Adjust the values such that each column will add up to 1,000,000. This assumes all samples have the same number of transcripts.

# %%
raw_cols_sums=raw_data[1:61].sum(axis = 0, skipna = True)
print(raw_cols_sums)
#Copy raw_data dataframe in order to replace the values with the normalized values
raw_data_normalized = raw_data.copy()
# Out:
# Gene_ID                    A1BG-AS1A2M-AS1AAASAACSAAED1AAGABAAK1AAMDCAAMP...
# Raw_10_HC_Auto_066_237                                                 49554
# Raw_11_Orkambi_006_Base                                                36371
# Raw_12_Orkambi_007_V2                                                  59219
# Raw_13_HC_Auto_068_239                                                 35697
#                                                  ...
# Raw_Orkambi_024_V2                                                     52219
# Raw_Orkambi_025_Base                                                   57331
# Raw_Orkambi_025_V2                                                     53249
# Raw_Orkambi_026_Base                                                   31577
# Raw_Orkambi_026_V2                                                     45619
# Length: 61, dtype: object

# %%
#Replace the first value of raw_cols_sums since it is a meaningless string of letters from gene names
raw_cols_sums.iat[0]=0
# Out:
# 49554

# %%
#Insert a row at the end of the original raw_data that consists of the sums of each column
raw_data.loc[len(raw_data.index)] = raw_cols_sums
raw_data.tail()
# Out:
#       Gene_ID  Raw_10_HC_Auto_066_237  Raw_11_Orkambi_006_Base  \
# 15566  ZYG11B                    2591                     2248
# 15567     ZYX                     826                     1097
# 15568   ZZEF1                    2552                     2668
# 15569    ZZZ3                    1743                     1095
# 15570       0                   49554                    36371
#
#        Raw_12_Orkambi_007_V2  Raw_13_HC_Auto_068_239  Raw_14_Orkambi_007_Base  \
# 15566                   2374                    2005                     2406
# 15567                    836                     610                     1431
# 15568                   2583                    2093                     2486
# 15569                   2415                    1046                     1343
# 15570                  59219                   35697                    43462
#
#        Raw_15_Orkambi_009_V2  Raw_16_HC_Auto_072_243  Raw_17_Orkambi_009_Base  \
# 15566                   3574                    4167                     4939
# 15567                   1166                    1411                     3067
# 15568                   2645                    3005                     4363
# 15569                   2157                    2279                     2001
# 15570                  64669                   64171                    67510
#
#        Raw_18_Orkambi_010_V2  ...  Raw_Orkambi_021_Base  Raw_Orkambi_021_V2  \
# 15566                   3513  ...                  3103                3112
# 15567                   2651  ...                  1592                1118
# 15568                   3036  ...                  2413                2023
# 15569                   1690  ...                  1579                1734
# 15570                  60646  ...                 45774               48848
#
#        Raw_Orkambi_022_Base  Raw_Orkambi_022_V2  Raw_Orkambi_024_Base  \
# 15566                  1895                4289                  2191
# 15567                   950                2321                  1160
# 15568                   960                3538                  2939
# 15569                   654                2152                  1153
# 15570                 18034               60077                 33020
#
#        Raw_Orkambi_024_V2  Raw_Orkambi_025_Base  Raw_Orkambi_025_V2  \
# 15566                2274                  2857                3537
# 15567                1215                  1144                 872
# 15568                3225                  2370                2050
# 15569                1772                  1768                1428
# 15570               52219                 57331               53249
#
#        Raw_Orkambi_026_Base  Raw_Orkambi_026_V2
# 15566                  1056                2432
# 15567                  2198                 876
# 15568                  4532                2432
# 15569                   946                1362
# 15570                 31577               45619
#
# [5 rows x 61 columns]

# %% [markdown]
# #Iterate through dataframe
# #for i in range(len(raw_data)):
#     #for j in range(1, len(raw_data.columns)):
#         #print(raw_data.iat[i,j])

# %%
#For each gene, divide it by its corresponding raw_cols_sum. Then multiply it by 1,000,000
#Save normalized dataframe as norm_cpm_df

for i in range(len(raw_data)):
    for j in range(1, len(raw_data.columns)):
        raw_data_normalized.iat[i,j]=(int(raw_data.iat[i,j])*1000000)/int(raw_cols_sums[j])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/ipykernel_35931/761241670.py in <module>
#       4 for i in range(len(raw_data)):
#       5     for j in range(1, len(raw_data.columns)):
# ----> 6         raw_data_normalized.iat[i,j]=(int(raw_data.iat[i,j])*1000000)/int(raw_cols_sums[j])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2116             raise ValueError("Not enough indexers for scalar access (setting)!")
#    2117
# -> 2118         self.obj._set_value(*key, value=value, takeable=self._takeable)
#    2119
#    2120
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    3263             if takeable is True:
#    3264                 series = self._ixs(col, axis=1)
# -> 3265                 series._set_value(index, value, takeable=True)
#    3266                 return
#    3267
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_value(self, label, value, takeable)
#    1068         try:
#    1069             if takeable:
# -> 1070                 self._values[label] = value
#    1071             else:
#    1072                 loc = self.index.get_loc(label)
#
# IndexError: index 15570 is out of bounds for axis 0 with size 15570

# %%
#This is the normalized dataframe
raw_data_normalized.head()
# Out:
#     Gene_ID  Raw_10_HC_Auto_066_237  Raw_11_Orkambi_006_Base  \
# 0      A1BG                    1634                     1044
# 1  A1BG-AS1                     988                      852
# 2   A2M-AS1                    1493                     2969
# 3      AAAS                    3248                     2364
# 4      AACS                    4015                     3519
#
#    Raw_12_Orkambi_007_V2  Raw_13_HC_Auto_068_239  Raw_14_Orkambi_007_Base  \
# 0                   1891                    1288                     1472
# 1                   1418                     728                      874
# 2                   1046                    1316                      943
# 3                   3326                    2577                     2668
# 4                   3343                    3277                     3727
#
#    Raw_15_Orkambi_009_V2  Raw_16_HC_Auto_072_243  Raw_17_Orkambi_009_Base  \
# 0                   3030                    1947                     2073
# 1                   1329                    1246                     1125
# 2                    479                    1636                      666
# 3                   2211                    3786                     2014
# 4                   4066                    3397                     3599
#
#    Raw_18_Orkambi_010_V2  ...  Raw_Orkambi_021_Base  Raw_Orkambi_021_V2  \
# 0                   1187  ...                  2468                1821
# 1                    626  ...                   873                 736
# 2                   1038  ...                   349                 470
# 3                   2489  ...                  2840                1453
# 4                   3314  ...                  4194                3214
#
#    Raw_Orkambi_022_Base  Raw_Orkambi_022_V2  Raw_Orkambi_024_Base  \
# 0                  1718                2080                  1332
# 1                  1441                1448                   696
# 2                  2218                1731                 11205
# 3                  1552                2962                  1877
# 4                  3937                3795                  3937
#
#    Raw_Orkambi_024_V2  Raw_Orkambi_025_Base  Raw_Orkambi_025_V2  \
# 0                1493                  1971                1840
# 1                1378                  1290                1032
# 2                3810                  1412                 563
# 3                4193                  3069                1990
# 4                3542                  3453                2140
#
#    Raw_Orkambi_026_Base  Raw_Orkambi_026_V2
# 0                  1203                1534
# 1                  2026                1161
# 2                  7220                 723
# 3                  5066                2652
# 4                  4148                3441
#
# [5 rows x 61 columns]

# %%
#Analyze data based on the following genes, make a subset of raw data based on the selected genes
#New dataframe with selected 
top10_ci_genes = ['LOC105372578','MCEMP1','MMP9','SOCS3','ANXA3','G0S2','IL1R2','PFKFB3','OSM','SEMA6B']

# %%
#Make a logic statement to check if the gene ID from the list of genes is found in the Gene_ID column
#Filter dataframe, save it to norm_cpm_df, print new filtered dataframe
logic_top10_genes=raw_data_normalized.Gene_ID.isin(top10_ci_genes)
norm_cpm_df=raw_data_normalized[logic_top10_genes]
norm_cpm_df
# Out:
#             Gene_ID  Raw_10_HC_Auto_066_237  Raw_11_Orkambi_006_Base  \
# 555           ANXA3                   25285                    35605
# 4206           G0S2                     565                     2721
# 5313          IL1R2                   25265                    46850
# 6886   LOC105372578                    1594                     3794
# 8139         MCEMP1                    2683                     2447
# 8458           MMP9                   22056                    34533
# 9470            OSM                    3148                     7368
# 9800         PFKFB3                   18141                    30051
# 11818        SEMA6B                     565                      439
# 12605         SOCS3                   30572                    66124
#
#        Raw_12_Orkambi_007_V2  Raw_13_HC_Auto_068_239  Raw_14_Orkambi_007_Base  \
# 555                     9895                   44569                   177327
# 4206                     996                     784                     4164
# 5313                   23337                   44681                    88836
# 6886                    1182                    2549                    17210
# 8139                    1300                    2549                    17325
# 8458                   39345                   31627                   219064
# 9470                    2516                    4426                    23537
# 9800                   12968                   33560                   143780
# 11818                    574                     532                     1472
# 12605                  19942                   44653                   203258
#
#        Raw_15_Orkambi_009_V2  Raw_16_HC_Auto_072_243  Raw_17_Orkambi_009_Base  \
# 555                    54570                   39940                   339105
# 4206                    4963                     997                     6236
# 5313                   74502                   41140                   113864
# 6886                    6401                    1683                    47948
# 8139                    5010                    2290                    34587
# 8458                  155221                   26320                   377025
# 9470                   10855                    4410                    30943
# 9800                   35596                   31213                   210502
# 11818                    773                     498                     1821
# 12605                  75476                   44708                   206221
#
#        Raw_18_Orkambi_010_V2  ...  Raw_Orkambi_021_Base  Raw_Orkambi_021_V2  \
# 555                   216749  ...                113994              131898
# 4206                    5969  ...                  4391                3541
# 5313                  102578  ...                 65801               85407
# 6886                   46103  ...                  9415               13183
# 8139                   26959  ...                 15489                9314
# 8458                  158163  ...                157600               81252
# 9470                   33472  ...                 18569               16541
# 9800                  243593  ...                110564               82418
# 11818                   3693  ...                  2381                1760
# 12605                 370428  ...                167453              149217
#
#        Raw_Orkambi_022_Base  Raw_Orkambi_022_V2  Raw_Orkambi_024_Base  \
# 555                  161029              168816                 73743
# 4206                   5434                7956                  1090
# 5313                 118054               82244                 73561
# 6886                  51846               57492                  8843
# 8139                   5766               13732                  2604
# 8458                  82067              241773                 40642
# 9470                  28279               23103                  6147
# 9800                 103859              133628                 28740
# 11818                  1885                2113                   333
# 12605                341632              239126                 54603
#
#        Raw_Orkambi_024_V2  Raw_Orkambi_025_Base  Raw_Orkambi_025_V2  \
# 555                 36059                 91660              177280
# 4206                 1014                  3000                3417
# 5313                41479                 56025              102912
# 6886                 2719                  6383               12188
# 8139                 1876                  6907                7943
# 8458                24646                 80305              137035
# 9470                 4117                 12122               17765
# 9800                24607                 57176               58742
# 11818                 344                  1290                1389
# 12605               35772                116708              185186
#
#        Raw_Orkambi_026_Base  Raw_Orkambi_026_V2
# 555                    9532               62298
# 4206                    538                2652
# 5313                  45666               54911
# 6886                   1045                7365
# 8139                   1805                3003
# 8458                  35500               57717
# 9470                   2153                7957
# 9800                  40029               39676
# 11818                   443                 591
# 12605                 17449               73587
#
# [10 rows x 61 columns]

# %% [markdown]
# The columns of the dataframe are labeled as such:
#
# any column name that has the term HC is a Health Control
#
# any column with Base is a patient with CF but no Treatment
#
# any column with V2 is a CF patient with treatment

# %%
# Separate filtered dataframe by selected genes into the healthy and cystic fibrosis data frames 
#Transpose resulting dataframes and add the corresponding labels.

# %%
df=pd.DataFrame()
df['new'] = data_df['Raw_10_HC_Auto_066_237'] + df['Raw_10_HC_Auto_066_237']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Raw_10_HC_Auto_066_237'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/ipykernel_35931/1010272979.py in <module>
#       1 df=pd.DataFrame()
# ----> 2 df['new'] = data_df['Raw_10_HC_Auto_066_237'] + df['Raw_10_HC_Auto_066_237']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Raw_10_HC_Auto_066_237'
